# %% [markdown]
# # Data-X Spring 2019: Homework 04
#
#
# ## Name: Miran Tafazzul Hussain Junaidi
#
# ## SID: 3034487132
#
# In this homework, you will do some exercises with plotting.
#
# REMEMBER TO DISPLAY ALL OUTPUTS. If the question asks you to do something, make sure to print your results.

# %% [markdown]
# ### 1.
# ### Data:
# __Data Source__:
# Data file is uploaded to bCourses and is named: __Energy.csv__
#
# The dataset was created by Angeliki Xifara ( Civil/Structural Engineer) and was processed by Athanasios Tsanas, Oxford Centre for Industrial and Applied Mathematics, University of Oxford, UK).
#
# __Data Description__:
#
# The dataset contains eight attributes of a building (or features, denoted by X1...X8) and response being the heating load on the building, y1.
#
# * X1	Relative Compactness
# * X2	Surface Area
# * X3	Wall Area
# *  X4	Roof Area
# *  X5	Overall Height
# * X6	Orientation
# *  X7	Glazing Area
# *  X8	Glazing Area Distribution
# *  y1	Heating Load

# %% [markdown]
# #### Q1.1
# Read the data file in python. Check if there are any NaN values, and print the results.

# %%
# your code
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("Energy.csv")
if data.isnull().sum().sum()== 0:
    print("There are no Empty places in the data and is ready to use")
data.head()
# Out:
# There are no Empty places in the data and is ready to use
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84

# %% [markdown]
# #### Q 1.2
# Describe (using python function) data features in terms of type, distribution range (max and min), and mean values.

# %%
# your code
count = 0
def data_analysis(i , count):
    print('The feture', count+1, " is of type ", type(data[i][1]) )
    print("its mean is ", data[i].mean())
    print('Its maxinmum value is ' ,  data[i].max())
    print('Its minimum value is ' ,  data[i].min())
    print()
    print()
for i in data : 
    data_analysis(i, count)
    count+=1
# Out:
# The feture 1  is of type  <class 'numpy.float64'>
# its mean is  0.7641666666666677
# Its maxinmum value is  0.98
# Its minimum value is  0.62
#
#
# The feture 2  is of type  <class 'numpy.float64'>
# its mean is  671.7083333333334
# Its maxinmum value is  808.5
# Its minimum value is  514.5
#
#
# The feture 3  is of type  <class 'numpy.float64'>
# its mean is  318.5
# Its maxinmum value is  416.5
# Its minimum value is  245.0
#
#
# The feture 4  is of type  <class 'numpy.float64'>
# its mean is  176.60416666666666
# Its maxinmum value is  220.5
# Its minimum value is  110.25
#
#
# The feture 5  is of type  <class 'numpy.float64'>
# its mean is  5.25
# Its maxinmum value is  7.0
# Its minimum value is  3.5
#
#
# The feture 6  is of type  <class 'numpy.int64'>
# its mean is  3.5
# Its maxinmum value is  5
# Its minimum value is  2
#
#
# The feture 7  is of type  <class 'numpy.float64'>
# its mean is  0.23437500000000186
# Its maxinmum value is  0.4
# Its minimum value is  0.0
#
#
# The feture 8  is of type  <class 'numpy.int64'>
# its mean is  2.8125
# Its maxinmum value is  5
# Its minimum value is  0
#
#
# The feture 9  is of type  <class 'numpy.float64'>
# its mean is  22.307200520833305
# Its maxinmum value is  43.1
# Its minimum value is  6.01

# %% [markdown]
# #### Q 1.3
# Plot feature distributions for all the attributes in the dataset (Hint - Histograms are one way to plot data distributions). This step should give you clues about data sufficiency.

# %%
# your code
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a195eb978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a194936d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1969c4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19692a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19768f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19792550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19794ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a197f50b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a197f50f0>]],
#       dtype=object)

# %%
plt.xlim(0,1) 
plt.xticks(np.arange(1)) 
plt.hist(data['X1'])
# Out:
# (array([128., 128.,  64., 128.,  64.,  64.,  64.,  64.,   0.,  64.]),
#  array([0.62 , 0.656, 0.692, 0.728, 0.764, 0.8  , 0.836, 0.872, 0.908,
#         0.944, 0.98 ]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(0,10) 
plt.xticks(np.arange(11))
plt.hist(data['X5'])
# Out:
# (array([384.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 384.]),
#  array([3.5 , 3.85, 4.2 , 4.55, 4.9 , 5.25, 5.6 , 5.95, 6.3 , 6.65, 7.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(0,10) 
plt.xticks(np.arange(11)) 
plt.hist(data['X6'])
# Out:
# (array([192.,   0.,   0., 192.,   0.,   0., 192.,   0.,   0., 192.]),
#  array([2. , 2.3, 2.6, 2.9, 3.2, 3.5, 3.8, 4.1, 4.4, 4.7, 5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(0,1) 
plt.xticks(np.arange(0,1,0.1)) 
plt.hist(data['X7'])
# Out:
# (array([ 48.,   0., 240.,   0.,   0.,   0., 240.,   0.,   0., 240.]),
#  array([0.  , 0.04, 0.08, 0.12, 0.16, 0.2 , 0.24, 0.28, 0.32, 0.36, 0.4 ]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(0,10) 
plt.xticks(np.arange(11)) 
plt.hist(data['X8'])
# Out:
# (array([ 48.,   0., 144.,   0., 144.,   0., 144.,   0., 144., 144.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(500,900) 
plt.xticks(np.arange(500,900, 50)) 
plt.hist(data['X2'])
# Out:
# (array([ 64.,  64.,  64.,  64.,  64., 128.,  64.,  64.,  64., 128.]),
#  array([514.5, 543.9, 573.3, 602.7, 632.1, 661.5, 690.9, 720.3, 749.7,
#         779.1, 808.5]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(200,500) 
plt.xticks(np.arange(200,500, 50)) 
plt.hist(data['X3'])
# Out:
# (array([ 64.,  64., 192.,   0., 192., 128.,   0.,  64.,   0.,  64.]),
#  array([245.  , 262.15, 279.3 , 296.45, 313.6 , 330.75, 347.9 , 365.05,
#         382.2 , 399.35, 416.5 ]),
#  <a list of 10 Patch objects>)

# %%
plt.xlim(0,300) 
plt.xticks(np.arange(0,300, 50)) 
plt.hist(data['X4'])
# Out:
# (array([ 64., 128.,   0., 192.,   0.,   0.,   0.,   0.,   0., 384.]),
#  array([110.25 , 121.275, 132.3  , 143.325, 154.35 , 165.375, 176.4  ,
#         187.425, 198.45 , 209.475, 220.5  ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Q1.4
# Create a combined line and scatter plot for attributes 'X1' and 'X2' with a marker (*). You can choose either of the attributes as x & y.  Label your axes and give a title to your plot.

# %%
# your code
x1 = data['X1']
x2 = data['X2']
plt.plot(x1,x2, marker='*');
plt.xlabel('data x1')
plt.ylabel('data x2')
plt.title('Relation between first and second paramaters')
plt.show()

# %%
plt.scatter(x1,x2, marker='*')
plt.xlabel('data x1')
plt.ylabel('data x2')
plt.title('Relation between first and second paramaters')
plt.show()

# %% [markdown]
# #### Q1.5
# Create a scatter plot for how 'Wall Area' changes with 'Relative Compactness'. Give different colors for different 'Overall Height' and different bubble sizes by 'Roof Area'. Label the axes and give a title. Add a legend to your plot.

# %%
# your code
sns.scatterplot(data['X3'], data['X1'] , hue = data['X5'] , size = data['X4'], data = data)

# %% [markdown]
# ### 2.
# #### Q 2.1a.
# Create a dataframe called `icecream` that has column `Flavor` with entries `Strawberry`, `Vanilla`, and `Chocolate` and another column with `Price` with entries `3.50`, `3.00`, and `4.25`. Print the dataframe.

# %%
# your code

icecream = {"Flavour" : ['Strawberry' ,'Vanilla', 'Chocolate' ] , "Price" : [3.50 , 3.00, 4.25]}
icecream = pd.DataFrame(icecream)
icecream
# Out:
#       Flavour  Price
# 0  Strawberry   3.50
# 1     Vanilla   3.00
# 2   Chocolate   4.25

# %% [markdown]
# #### Q 2.1b
# Create a bar chart representing the three flavors and their associated prices. Label the axes and give a title.

# %%
# your code
icecream.plot.bar(x = 'Flavour' , y = 'Price')

# %% [markdown]
# #### Q 2.2
# Create 9 random plots in a figure (Hint: There is a numpy function for generating random data).
#
# The top three should be scatter plots (one with green dots, one with purple crosses, and one with blue triangles. The middle three graphs should be a line graph, a horizontal bar chart, and a histogram. The bottom three graphs should be trignometric functions (one sin, one cosine, one tangent). Keep in mind the range and conditions for the trignometric functions.
#
# ##### All these plots should be on the same figure and not 9 independent figures.

# %%
# your code
f, ax = plt.subplots(nrows=3,ncols=3)
x = np.random.randn(30)
y = np.random.randn(30)
ax[0,0].scatter(x, y, color = 'green')
x = np.random.randn(30)
y = np.random.randn(30)
ax[0,1].scatter(x, y, color = 'purple' , marker='x')
x = np.random.randn(30)
y = np.random.randn(30)
ax[0,2].scatter(x, y, color = 'blue', marker = '^')
x = np.random.randn(30)
y = np.random.randn(30)
ax[1,0].plot(x,y)
x = np.random.randn(30)
y = np.random.randn(30)
ax[1,1].barh(x,y)
x = np.random.randn(30)
y = np.random.randn(30)
ax[1,2].hist(x)
x = np.random.rand(100)
y = np.sin(x)
ax[2,0].scatter(x,y)
x = np.random.rand(100)
y = np.cos(x)
ax[2,1].scatter(x,y)
x = np.random.rand(1000)*2
y = np.tan(x)
ax[2,2].scatter(x,y)
#plt.colorbar(); #this will add a color bar to the right

# %% [markdown]
# ### 3.
# #### Q 3.1
#
# Load the 'Iris' dataset using seaborn.
# Create a box plot for the attributes 'sepal_length', sepal_width', 'petal_length' and 'petal_width' in the Iris dataset.

# %%
# your code
data = sns.load_dataset('iris')
data.boxplot(column = ['sepal_length' , 'sepal_width', 'petal_length' , 'petal_width'])

# %% [markdown]
# #### Q 3.2
# In a few sentences explain what can you interpret from the above box plot.

# %%
'This plot firstly explains and gives the rough estimate of the range of the distribution. Gives us the idea of where the mean lies. This plot also explaines that the petal_length is highly distributed since it has a high inter quartile range, Also gives an idea about quiet a few outlyers for sepal_width'
# Out:
# 'This plot firstly explains and gives the rough estimate of the range of the distribution. Gives us the idea of where the mean lies. This plot also explaines that the petal_length is highly distributed since it has a high inter quartile range, Also gives an idea about quiet a few outlyers for sepal_width'

# %% [markdown]
# #### Q 4.
# The data files needed:
#
# `google_data.txt, ny_temps.txt & yahoo_data.txt`
#
# Use your knowledge with `Python, NumPy, pandas and matplotlib` to reproduce the plot below:
#
# ![](answer.png?raw=true)

# %%
# your code
df1 = pd.read_csv('google_data.txt' , delimiter = '\t')
df2 = pd.read_csv('ny_temps.txt' , delimiter = '\t')
df3 = pd.read_csv('yahoo_data.txt' , delimiter = '\t')

ax = df1.plot('Modified Julian Date', 'Stock Value', color='Green');
ax2 = ax.twinx()
ax2.set_ylim(-150, 100)
df2.plot('Modified Julian Date', 'Max Temperature', color='Blue', ax = ax2);
df3.plot('Modified Julian Date', 'Stock Value', color='magenta', ax=ax );
plt.title('New Yort Temprature, Google, Yahoo!')
plt.show()
